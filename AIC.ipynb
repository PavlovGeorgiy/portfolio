# %% [markdown]
# <a href="https://colab.research.google.com/github/PavlovGeorgiy/portfolio/blob/main/AIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('aic.csv')

df.head(10)
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536365    84029E   RED WOOLLY HOTTIE WHITE HEART.         6
# 1    536367     84879    ASSORTED COLOUR BIRD ORNAMENT        32
# 2    536367     21755         LOVE BUILDING BLOCK WORD         3
# 3    536368     22914     BLUE COAT RACK PARIS FASHION         3
# 4    536373    84406B   CREAM CUPID HEARTS COAT HANGER         8
# 5    536375    82494L      WOODEN FRAME ANTIQUE WHITE          6
# 6    536378     21033  JUMBO BAG CHARLIE AND LOLA TOYS        10
# 7    536381     82567        AIRLINE LOUNGE,METAL SIGN         2
# 8    536381     21169  YOU'RE CONFUSING ME METAL SIGN          3
# 9    536381     21175      GIN + TONIC DIET METAL SIGN         2
#
#     InvoiceDate UnitPrice  CustomerID         Country
# 0  12/1/19 8:26      3,39     17850.0  United Kingdom
# 1  12/1/19 8:34      1,69     13047.0  United Kingdom
# 2  12/1/19 8:34      5,95     13047.0  United Kingdom
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54214 entries, 0 to 54213
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    54214 non-null  object
#  1   StockCode    54214 non-null  object
#  2   Description  54080 non-null  object
#  3   Quantity     54214 non-null  int64
#  4   InvoiceDate  54214 non-null  object
#  5   UnitPrice    54214 non-null  object
#  6   CustomerID   40643 non-null  float64
#  7   Country      54214 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.3+ MB

# %%
list(df['Country'].unique())
# Out:
# ['United Kingdom',
#  'Australia',
#  'Netherlands',
#  'Norway',
#  'EIRE',
#  'Germany',
#  'France',
#  'Switzerland',
#  'Spain',
#  'Poland',
#  'Italy',
#  'Belgium',
#  'Lithuania',
#  'Japan',
#  'Portugal',
#  'Iceland',
#  'Channel Islands',
#  'Denmark',
#  'Cyprus',
#  'Sweden',
#  'Finland',
#  'Austria',
#  'Israel',
#  'Greece',
#  'Hong Kong',
#  'Singapore',
#  'Lebanon',
#  'United Arab Emirates',
#  'Czech Republic',
#  'Canada',
#  'Unspecified',
#  'Brazil',
#  'USA',
#  'European Community',
#  'Bahrain',
#  'Malta',
#  'RSA']

# %%
list(df['Description'].unique())
# Out:
# ['RED WOOLLY HOTTIE WHITE HEART.',
#  'ASSORTED COLOUR BIRD ORNAMENT',
#  'LOVE BUILDING BLOCK WORD',
#  'BLUE COAT RACK PARIS FASHION',
#  'CREAM CUPID HEARTS COAT HANGER',
#  'WOODEN FRAME ANTIQUE WHITE ',
#  'JUMBO BAG CHARLIE AND LOLA TOYS',
#  'AIRLINE LOUNGE,METAL SIGN',
#  "YOU'RE CONFUSING ME METAL SIGN ",
#  'GIN + TONIC DIET METAL SIGN',
#  'YELLOW BREAKFAST CUP AND SAUCER',
#  'FELT EGG COSY WHITE RABBIT ',
#  'SET OF 6 FUNKY BEAKERS',
#  'EDWARDIAN PARASOL BLACK',
#  'BLUE OWL SOFT TOY',
#  'RED TOADSTOOL LED NIGHT LIGHT',
#  'RECYCLING BAG RETROSPOT ',
#  'ALARM CLOCK BAKELIKE GREEN',
#  'SET 3 WICKER OVAL BASKETS W LIDS',
#  'SET OF 3 COLOURED  FLYING DUCKS',
#  'ENAMEL FIRE BUCKET CREAM',
#  'LUNCH BAG DOLLY GIRL DESIGN',
#  'JUMBO  BAG BAROQUE BLACK WHITE',
#  'FIVE HEART HANGING DECORATION',
#  'HOMEMADE JAM SCENTED CANDLES',
#  'ALARM CLOCK BAKELIKE RED ',
#  'SMALL HEART MEASURING SPOONS',
#  'HANGING HEART ZINC T-LIGHT HOLDER',
#  'PHOTO CUBE',
# ...

# %%
len(list(df['Description'].unique()))
# Out:
# 3402

# %%
len(list(df['StockCode'].unique()))
# Out:
# 3351
